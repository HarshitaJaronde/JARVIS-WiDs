# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\HARSHITA\\Downloads\\Dataset.csv")
df
# Out:
#                                   Speech         Intent
# 0                              send mail     Send Email
# 1                             send email     Send Email
# 2                   hey jarvis send mail     Send Email
# 3                   mind to send a mail?     Send Email
# 4                                  email     Send Email
# 5                  mind to send a email?     Send Email
# 6                         compose a mail     Send Email
# 7                           draft a mail     Send Email
# 8                     please send a mail     Send Email
# 9                         send a message     Send Email
# 10                          set reminder   Set Reminder
# 11                             remind me   Set Reminder
# 12                    give me a heads up   Set Reminder
# 13               hey jarvis set reminder   Set Reminder
# 14                   jarvis remind me to   Set Reminder
# 15           make sure I don’t forget to   Set Reminder
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test = train_test_split(df.Speech, df.Intent, test_size = 0.1, random_state=21)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
clf = Pipeline([('vectorizer', CountVectorizer()),('nb',LogisticRegression())])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()),
#                 ('nb', LogisticRegression())])

# %%
y_pred = clf.predict(X_test)
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
clf.predict(X_test[:5])
# Out:
# array(['Send Email', 'Greetings', 'Greetings', 'Search Google',
#        'Set Reminder'], dtype=object)

# %%
y_test[:5]
# Out:
# 7        Send Email
# 45        Greetings
# 44        Greetings
# 25    Search Google
# 14     Set Reminder
# Name: Intent, dtype: object

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#                precision    recall  f1-score   support
#
#     Greetings       1.00      1.00      1.00         2
# Search Google       1.00      1.00      1.00         1
#    Send Email       1.00      1.00      1.00         2
#  Set Reminder       1.00      1.00      1.00         1
#
#      accuracy                           1.00         6
#     macro avg       1.00      1.00      1.00         6
#  weighted avg       1.00      1.00      1.00         6

# %%
import pickle 
cr = classification_report(y_test, y_pred)
with open('cr_pickle','wb') as f:
    pickle.dump(cr,f)

# %%
with open('cr_pickle','rb') as f:
    cr = pickle.load(f)

# %%
print(cr)
# Out:
#                precision    recall  f1-score   support
#
#     Greetings       1.00      1.00      1.00         2
# Search Google       1.00      1.00      1.00         1
#    Send Email       1.00      1.00      1.00         2
#  Set Reminder       1.00      1.00      1.00         1
#
#      accuracy                           1.00         6
#     macro avg       1.00      1.00      1.00         6
#  weighted avg       1.00      1.00      1.00         6

# %%
#CLI, for printing category
user = input("Enter a Phrase: ")
phrase = [user]
print(clf.predict(phrase))
# Out:
# Enter a Phrase:  hey whats up
# ['Greetings']
